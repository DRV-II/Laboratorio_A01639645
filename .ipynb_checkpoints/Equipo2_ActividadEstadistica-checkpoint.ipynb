# %% [markdown]
# # Actividad Evaluable: Obtención de estadisticas descriptivas

# %% [markdown]
# ## Equipo 2

# %% [markdown]
# David Román Velasco - A01639645

# %% [markdown]
# Edgar Cruz Vazquez - A01730577

# %% [markdown]
# Luis Yair Ruiz Rodriguez - A01639766

# %% [markdown]
# Javier Perez Santiago - A01662438

# %% [markdown]
# Ernesto Reynoso Lizarraga - A01639915

# %% [markdown]
# ## Importación de librerías

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import random

# %% [markdown]
# **Se da lectura al archivo csv**

# %%
df = pd.read_csv("Beneficiarios_emb_mayores.csv")

# %% [markdown]
# **Comando shape el cual nos arroja el número de filas y columnas**

# %%
df.shape
# Out:
# (1133, 17)

# %% [markdown]
# **Comando info el cual nos muestra el tipo de dato en cada columna**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1133 entries, 0 to 1132
# Data columns (total 17 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   PROGRAMA                                1133 non-null   object
#  1   COMPONENTE                              1133 non-null   object
#  2   UNIDAD ADMINISTRATIVA                   1133 non-null   object
#  3   CLAVE PRESUPUESTARIA                    1133 non-null   object
#  4   CLAVE ESTADO                            1133 non-null   int64
#  5   NOMBRE ESTADO                           1133 non-null   object
#  6   CLAVE MUNICIPIO                         1133 non-null   int64
#  7   NOMBRE MUNICIPIO                        1133 non-null   object
#  8   CLAVE LOCALIDAD                         1133 non-null   int64
#  9   NOMBRE LOCALIDAD                        1133 non-null   object
# ...

# %% [markdown]
# **Comando head el cual muestra los primeros elementos en la estructura**

# %%
df.head()
# Out:
#                                             PROGRAMA  \
# 0  PROGRAMA DE APOYO A LA INVERSION EN EQUIPAMIEN...
# 1  PROGRAMA DE APOYO A LA INVERSION EN EQUIPAMIEN...
# 2  PROGRAMA DE APOYO A LA INVERSION EN EQUIPAMIEN...
# 3  PROGRAMA DE APOYO A LA INVERSION EN EQUIPAMIEN...
# 4  PROGRAMA DE APOYO A LA INVERSION EN EQUIPAMIEN...
#
#                                           COMPONENTE  \
# 0  MODERNIZACION DE LA FLOTA PESQUERA Y RACIONALI...
# 1  MODERNIZACION DE LA FLOTA PESQUERA Y RACIONALI...
# 2  MODERNIZACION DE LA FLOTA PESQUERA Y RACIONALI...
# 3  MODERNIZACION DE LA FLOTA PESQUERA Y RACIONALI...
# 4  MODERNIZACION DE LA FLOTA PESQUERA Y RACIONALI...
#
#                   UNIDAD ADMINISTRATIVA CLAVE PRESUPUESTARIA  CLAVE ESTADO  \
# 0  DIRECCION GENERAL DE INFRAESTRUCTURA             S261/4DB             2
# 1  DIRECCION GENERAL DE INFRAESTRUCTURA             S261/4DB             2
# 2  DIRECCION GENERAL DE INFRAESTRUCTURA             S261/4DB             2
# ...

# %% [markdown]
# **Generación de estadísticas descriptivas**

# %%
df.describe()
# Out:
#        CLAVE ESTADO  CLAVE MUNICIPIO  CLAVE LOCALIDAD  MONTO CONAPESCA  \
# count   1133.000000      1133.000000     1.133000e+03     1.133000e+03
# mean      23.744042      8498.180053     6.924384e+07     1.483292e+06
# std        7.568753     12422.421245     1.138436e+08     1.689144e+06
# min        2.000000         1.000000     1.000000e+00     4.310345e+04
# 25%       25.000000        12.000000     1.000000e+00     5.680000e+05
# 50%       26.000000        38.000000     1.907000e+03     9.986845e+05
# 75%       26.000000     25012.000000     2.500106e+08     1.831635e+06
# max       31.000000     31059.000000     3.105900e+08     1.311865e+07
#
#         ANIO APOYO
# count  1133.000000
# mean   2014.729038
# std       1.896578
# min    2012.000000
# 25%    2013.000000
# 50%    2014.000000
# 75%    2016.000000
# max    2019.000000

# %% [markdown]
# **Líneas de comando en donde se filtro la columna año de apoyo para los años mayores de 2013**

# %%
more_than_100 = df[df['ANIO APOYO'] > 2013]
more_than_100
# Out:
#                                                PROGRAMA  \
# 300   PROGRAMA DE FOMENTO A LA PRODUCTIVIDAD PESQUER...
# 301   PROGRAMA DE FOMENTO A LA PRODUCTIVIDAD PESQUER...
# 302   PROGRAMA DE FOMENTO A LA PRODUCTIVIDAD PESQUER...
# 303   PROGRAMA DE FOMENTO A LA PRODUCTIVIDAD PESQUER...
# 304   PROGRAMA DE FOMENTO A LA PRODUCTIVIDAD PESQUER...
# ...                                                 ...
# 1128  PROGRAMA DE FOMENTO A LA PRODUCTIVIDAD PESQUER...
# 1129  PROGRAMA DE FOMENTO A LA PRODUCTIVIDAD PESQUER...
# 1130  PROGRAMA DE FOMENTO A LA PRODUCTIVIDAD PESQUER...
# 1131  PROGRAMA DE FOMENTO A LA PRODUCTIVIDAD PESQUER...
# 1132  PROGRAMA DE FOMENTO A LA PRODUCTIVIDAD PESQUER...
#
#                                              COMPONENTE  \
# 300   IMPULSO A LA CAPITALIZACION PESQUERA Y ACUICOL...
# 301   IMPULSO A LA CAPITALIZACION PESQUERA Y ACUICOL...
# 302   IMPULSO A LA CAPITALIZACION PESQUERA Y ACUICOL...
# 303   IMPULSO A LA CAPITALIZACION PESQUERA Y ACUICOL...
# ...

# %% [markdown]
# **Utilización de doble filtración para obtener datos con los requerimientos específicos**

# %%
double_filter = df[(df['ANIO APOYO']>2013) & (df['ANIO APOYO']<2016)]
double_filter
# Out:
#                                               PROGRAMA  \
# 300  PROGRAMA DE FOMENTO A LA PRODUCTIVIDAD PESQUER...
# 301  PROGRAMA DE FOMENTO A LA PRODUCTIVIDAD PESQUER...
# 302  PROGRAMA DE FOMENTO A LA PRODUCTIVIDAD PESQUER...
# 303  PROGRAMA DE FOMENTO A LA PRODUCTIVIDAD PESQUER...
# 304  PROGRAMA DE FOMENTO A LA PRODUCTIVIDAD PESQUER...
# ..                                                 ...
# 749  PROGRAMA DE FOMENTO A LA PRODUCTIVIDAD PESQUER...
# 750  PROGRAMA DE FOMENTO A LA PRODUCTIVIDAD PESQUER...
# 751  PROGRAMA DE FOMENTO A LA PRODUCTIVIDAD PESQUER...
# 752  PROGRAMA DE FOMENTO A LA PRODUCTIVIDAD PESQUER...
# 753  PROGRAMA DE FOMENTO A LA PRODUCTIVIDAD PESQUER...
#
#                                             COMPONENTE  \
# 300  IMPULSO A LA CAPITALIZACION PESQUERA Y ACUICOL...
# 301  IMPULSO A LA CAPITALIZACION PESQUERA Y ACUICOL...
# 302  IMPULSO A LA CAPITALIZACION PESQUERA Y ACUICOL...
# 303  IMPULSO A LA CAPITALIZACION PESQUERA Y ACUICOL...
# ...

# %% [markdown]
# **Obtención de media mediante el comando mean()**

# %%
rango = ['CLAVE ESTADO', 'CLAVE MUNICIPIO', 'CLAVE LOCALIDAD', 'MONTO CONAPESCA', 'ANIO APOYO']
for i in range(0, 4):
    print('Media de ', rango[i], ': ', df[rango[i]].mean())
# Out:
# Media de  CLAVE ESTADO :  23.74404236540159
# Media de  CLAVE MUNICIPIO :  8498.180052956752
# Media de  CLAVE LOCALIDAD :  69243838.97263901
# Media de  MONTO CONAPESCA :  1483291.6041491623

# %% [markdown]
# **Utilización de la media recortada**

# %%
for k in range(0, 4):
    sorted = df[rango[k]].sort_values()
    sorted
    sorted = sorted.reset_index(drop = True)
    sorted
    p = 5
    acum = 0
    for i in range(p, len(sorted) - p):
        acum += sorted[i]
    croppedMean =  acum / (len(sorted) - (2 * p))
    print('Media recortada de ', rango[k], ': ', croppedMean)
# Out:
# Media recortada de  CLAVE ESTADO :  23.808548530721282
# Media recortada de  CLAVE MUNICIPIO :  8435.563668744435
# Media recortada de  CLAVE LOCALIDAD :  68477577.40071237
# Media recortada de  MONTO CONAPESCA :  1440009.9619332147

# %% [markdown]
# **Medía ponderada**

# %%
for k in range(0, 4):
    weights = [random.random() for i in range(len(df[rango[k]]))]
    #print(weights)
    accWeightedValues = df[rango[k]].values.flatten().dot(weights)
    weightedMean = accWeightedValues / sum(weights)
    print('Media ponderada ', rango[k], ': ', weightedMean)
# Out:
# Media ponderada  CLAVE ESTADO :  23.88764608093714
# Media ponderada  CLAVE MUNICIPIO :  8412.736576238614
# Media ponderada  CLAVE LOCALIDAD :  67895953.30597153
# Media ponderada  MONTO CONAPESCA :  1458462.1765249188

# %% [markdown]
# **Obtención del dato moda mediante el comando mode()**

# %%
for i in range(0, 4):
    moda = pd.Series(df[rango[i]].values.flatten()).mode()[0]
    print('Moda ', rango[i], ': ', moda)
# Out:
# Moda  CLAVE ESTADO :  26
# Moda  CLAVE MUNICIPIO :  12
# Moda  CLAVE LOCALIDAD :  1
# Moda  MONTO CONAPESCA :  1000000.0

# %% [markdown]
# **Utilización del comando median(), para obtener el dato de la mediana**

# %%
for i in range(0, 4):
    print('Mediana ', rango[i], ': ', df[rango[i]].median())
# Out:
# Mediana  CLAVE ESTADO :  26.0
# Mediana  CLAVE MUNICIPIO :  38.0
# Mediana  CLAVE LOCALIDAD :  1907.0
# Mediana  MONTO CONAPESCA :  998684.5

# %% [markdown]
# **Utilización del comando var() para la obtención de la desviación estandar de la estructura**

# %%
for i in range(0, 4):
    print('Varianza ', rango[i], ': ', df[rango[i]].var())
    print('Desviación estándar ', rango[i], ': ', df[rango[i]].std())
# Out:
# Varianza  CLAVE ESTADO :  57.28601792046533
# Desviación estándar  CLAVE ESTADO :  7.56875273215246
# Varianza  CLAVE MUNICIPIO :  154316549.58416107
# Desviación estándar  CLAVE MUNICIPIO :  12422.421244836332
# Varianza  CLAVE LOCALIDAD :  1.2960363085213316e+16
# Desviación estándar  CLAVE LOCALIDAD :  113843590.44414102
# Varianza  MONTO CONAPESCA :  2853208462021.777
# Desviación estándar  MONTO CONAPESCA :  1689144.298756556
